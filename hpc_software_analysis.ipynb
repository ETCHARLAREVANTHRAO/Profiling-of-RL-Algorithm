# %%
pip install stable-baselines3[extra] tensorboard
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 57.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 42.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 23.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 44.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 7.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import gym
from stable_baselines3 import TD3
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import configure
import gymnasium as gym2 # Import gymnasium

# Create and wrap the environment
env = DummyVecEnv([lambda: Monitor(gym2.make("Pendulum-v1"))]) # Use gym2.make

# Set up logger for TensorBoard
log_dir = "./td3_tensorboard/"
new_logger = configure(log_dir, ["stdout", "tensorboard"])

# Initialize the model
model = TD3("MlpPolicy", env, verbose=1)
model.set_logger(new_logger)

# Train the model
model.learn(total_timesteps=50000)
import gym
from stable_baselines3 import TD3
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import configure
import gymnasium as gym2 # Import gymnasium

# Create and wrap the environment
env = DummyVecEnv([lambda: Monitor(gym2.make("Pendulum-v1"))]) # Use gym2.make

# Set up logger for TensorBoard
log_dir = "./td3_tensorboard/"
new_logger = configure(log_dir, ["stdout", "tensorboard"])

# Initialize the model
model = TD3("MlpPolicy", env, verbose=1)
model.set_logger(new_logger)

# Train the model
model.learn(total_timesteps=50000)

# Save model (optional)
model.save("td3_pendulum")
# Out:
# Logging to ./td3_tensorboard/
# Using cpu device
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.42e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 42        |
# |    time_elapsed    | 19        |
# |    total_timesteps | 800       |
# | train/             |           |
# |    actor_loss      | 16        |
# |    critic_loss     | 0.0274    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 699       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.44e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 38        |
# |    time_elapsed    | 42        |
# |    total_timesteps | 1600      |
# | train/             |           |
# ...

# %%
# !tensorboard --logdir=./td3_tensorboard/
# Out:
# 2025-04-13 09:34:40.950063: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744536880.985759    8561 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744536880.996527    8561 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-13 09:34:46.927488: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
# ...
